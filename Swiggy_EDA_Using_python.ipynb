# %% [markdown]
# # Swiggy Exploratory Data Analysis :
#    ## 1. Summary
#    ## 2. Import DataSet And Required Packages
#    ## 3. Dataset  information
#    ## 4. Data Cleaning
#    ## 5. Data Checks To Perform
#    ## 6. Exploratory Data Analysis(EDA)
#    ## 7. Insights
#    ## 8. Conclusion

# %% [markdown]
# # 1. Summary

# %%
### 📌 Objective:
The goal of this EDA is to explore and understand the dataset, identify key trends, and extract meaningful insights for decision-making.

### 📊 Dataset Summary:
- **Source: [Add dataset source or mention if it's internal]
- **Total Records: 197430 rows*
- **Total Features: 9 columns*
- **Type of Data: [Categorical / Numerical / Text ]
- **Main Fields: [State, City, Restaurant Name,	Location, Category	Price (INR),	Rating	]

### 🎯 Key Questions:
1. What are the most important patterns or correlations in the data?  
2. Which categories or groups perform best or worst?  
3. How are key variables distributed?  
4. Are there any outliers or missing values to handle?

## Goal:
- Explore restaurant ratings and pricing patterns  
- Identify popular cuisines and city-wise trends  
- Find relationships between price, rating, and delivery factors  
- Generate insights to help improve recommendations

# %% [markdown]
# # 2. Import DataSet And Required Packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 2.1 Dataset

# %%
df=pd.read_csv(r"C:\Users\kandr\Downloads\swiggy_all_menus_india.zip")

# %%
df
# Out:
#             State       City           Restaurant Name              Location  \
# 0       Karnataka  Bengaluru  Anand Sweets & Savouries  Rajarajeshwari Nagar
# 1       Karnataka  Bengaluru     Srinidhi Sagar Deluxe               Kengeri
# 2       Karnataka  Bengaluru     Srinidhi Sagar Deluxe               Kengeri
# 3       Karnataka  Bengaluru     Srinidhi Sagar Deluxe               Kengeri
# 4       Karnataka  Bengaluru     Srinidhi Sagar Deluxe               Kengeri
# ...           ...        ...                       ...                   ...
# 197425     Sikkim    Gangtok            Mama's Kitchen               Gangtok
# 197426     Sikkim    Gangtok            Mama's Kitchen               Gangtok
# 197427     Sikkim    Gangtok            Mama's Kitchen               Gangtok
# 197428     Sikkim    Gangtok            Mama's Kitchen               Gangtok
# 197429     Sikkim    Gangtok            Mama's Kitchen               Gangtok
#
# ...

# %% [markdown]
# # 3 .Dataset Informations

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 197430 entries, 0 to 197429
# Data columns (total 9 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   State            197430 non-null  object
#  1   City             197430 non-null  object
#  2   Restaurant Name  197430 non-null  object
#  3   Location         197430 non-null  object
#  4   Category         197430 non-null  object
#  5   Dish Name        197430 non-null  object
#  6   Price (INR)      197430 non-null  float64
#  7   Rating           197430 non-null  float64
#  8   Rating Count     197430 non-null  int64
# dtypes: float64(2), int64(1), object(6)
# memory usage: 13.6+ MB

# %% [markdown]
# ## 3.1 Check Statistics Of Dataset

# %%
df.describe()
# Out:
#          Price (INR)         Rating   Rating Count
# count  197430.000000  197430.000000  197430.000000
# mean      268.512920       2.613625      28.321805
# std       219.338363       2.145706      87.542593
# min         0.950000       0.000000       0.000000
# 25%       139.000000       0.000000       0.000000
# 50%       229.000000       3.900000       2.000000
# 75%       329.000000       4.500000      15.000000
# max      8000.000000       5.000000     999.000000

# %% [markdown]
# ## 3.2 Check The Number Of Unique Values Of Each Column

# %%
df.nunique()
# Out:
# State                 28
# City                  28
# Restaurant Name      993
# Location             977
# Category            4972
# Dish Name          59064
# Price (INR)         2755
# Rating                37
# Rating Count         963
# dtype: int64

# %% [markdown]
# ## 3.3 Total Columns

# %%
df.columns
# Out:
# Index(['State', 'City', 'Restaurant Name', 'Location', 'Category', 'Dish Name',
#        'Price (INR)', 'Rating', 'Rating Count'],
#       dtype='object')

# %% [markdown]
# ## 3.4 Shpe of Dataframe

# %%
df.shape
# Out:
# (197430, 9)

# %% [markdown]
# ## 3.5 Dataset Size

# %%
df.size
# Out:
# 1776870

# %% [markdown]
# ## 3.6 Dataset Top 5 Rows

# %%
df.head()
# Out:
#        State       City           Restaurant Name              Location  \
# 0  Karnataka  Bengaluru  Anand Sweets & Savouries  Rajarajeshwari Nagar
# 1  Karnataka  Bengaluru     Srinidhi Sagar Deluxe               Kengeri
# 2  Karnataka  Bengaluru     Srinidhi Sagar Deluxe               Kengeri
# 3  Karnataka  Bengaluru     Srinidhi Sagar Deluxe               Kengeri
# 4  Karnataka  Bengaluru     Srinidhi Sagar Deluxe               Kengeri
#
#       Category             Dish Name  Price (INR)  Rating  Rating Count
# 0        Snack  Butter Murukku-200gm        133.9     0.0             0
# 1  Recommended            Badam Milk         52.0     4.5            25
# 2  Recommended        Chow Chow Bath        117.0     4.7            48
# 3  Recommended           Kesari Bath         65.0     4.6            65
# 4  Recommended            Mix Raitha        130.0     0.0             0

# %% [markdown]
# ## 3.7 Dataset Buttom 5 Rows

# %%
df.tail()
# Out:
#          State     City Restaurant Name Location Category  \
# 197425  Sikkim  Gangtok  Mama's Kitchen  Gangtok    Momos
# 197426  Sikkim  Gangtok  Mama's Kitchen  Gangtok    Momos
# 197427  Sikkim  Gangtok  Mama's Kitchen  Gangtok    Momos
# 197428  Sikkim  Gangtok  Mama's Kitchen  Gangtok    Momos
# 197429  Sikkim  Gangtok  Mama's Kitchen  Gangtok    Momos
#
#                                                 Dish Name  Price (INR)  \
# 197425  Soya cheese chilli momo                       ...        112.0
# 197426  Kurkure momo fried                            ...        140.0
# 197427                                Chilli cheese momo         126.0
# 197428                                   Veg Momos (8 Pc)         85.0
# 197429                                          Soya Momo        100.0
#
#         Rating  Rating Count
# 197425     0.0             0
# 197426     0.0             0
# 197427     0.0             0
# 197428     0.0             0
# 197429     0.0             0

# %% [markdown]
# ## 3.8 Dataset Sample Rows

# %%
df.sample(3)
# Out:
#             State        City      Restaurant Name     Location  \
# 101690  Rajasthan      Jaipur    A Cheesy Sandwich  Laxmi Vihar
# 148530      Assam    Guwahati             Food Exx     BIRKUCHI
# 113756     Punjab  Chandigarh  Pastas By Pizza Hut     Zirakpur
#
#                      Category                           Dish Name  \
# 101690  Flavoured Cold Coffee  Butterscotch flavoured Cold coffee
# 148530          Papad & Raita                         Onion Salad
# 113756                 Pastas              Penne McN Cheese Pasta
#
#         Price (INR)  Rating  Rating Count
# 101690         79.0     0.0             0
# 148530         90.0     0.0             0
# 113756        209.0     2.0             3

# %% [markdown]
# ## 3.9 Unique Values In Every Column

# %%
for i in df.columns:
        print(f"{i}:{df[i].unique()}")
        print(150*"*")

# %% [markdown]
# # 4. Data Cleaning:

# %% [markdown]
# ## 4.1 Check Missing Values

# %%
df.isnull().sum()
# Out:
# State              0
# City               0
# Restaurant Name    0
# Location           0
# Category           0
# Dish Name          0
# Price (INR)        0
# Rating             0
# Rating Count       0
# dtype: int64

# %% [markdown]
# ### The are no missing values in the dataset

# %% [markdown]
# ### 4.2 Check Duplicates:

# %%
df.duplicated().sum()
# Out:
# 6104

# %% [markdown]
# ## 4.3 Drop Duplicates

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# # 5.Data Checks To Perform

# %%
df.isnull().sum()
# Out:
# State              0
# City               0
# Restaurant Name    0
# Location           0
# Category           0
# Dish Name          0
# Price (INR)        0
# Rating             0
# Rating Count       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### -There are no missing values and duplicates.
# ### - dataset is  ready to analysis

# %% [markdown]
# # 6 .Exploratory Data Analysis (EDA)

# %% [markdown]
# ### 6 Univariate Analysis

# %% [markdown]
# ### 6.1 Rating Distribution

# %%
plt.figure(figsize=(8,4))
plt.hist(df["Rating"],bins=20,color="lightgreen",edgecolor="black")
plt.title("Rating Distribution")
plt.xlabel("Rating Count")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ## insights

# %% [markdown]
# insights:
# #1.The price distribution shows that most restaurants are priced between ₹200 and ₹600.
# #2.This reflects Swiggy’s focus on affordable and mid-range dining options.
# #3.Only a small portion of restaurants fall in the premium price segment.

# %% [markdown]
# ### 6.2 Price Distribution

# %%
#2.Price Distribution
plt.figure(figsize=(6,4))
sns.histplot(df["Price (INR)"],bins=30,color="green",edgecolor="black",kde=True)
plt.title("Price Distribution")
plt.xlabel("Price (INR)")
plt.show()

# %% [markdown]
# ## Insights

# %%
Insights: Price Distribution
#1.The majority of restaurants fall within the ₹200–₹600 price range,
#2.suggesting that Swiggy’s offerings target affordable and mid-tier customers.
#3.High-priced premium restaurants are comparatively rare.

# %% [markdown]
# ### 6.3 price Range

# %%
plt.figure(figsize=(6,5))
sns.violinplot(data=df,x="Price (INR)")
plt.title("price Range", fontsize=14)
plt.xlabel("State", fontsize=12)
plt.ylabel("Price Range", fontsize=12)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Insights:

# %%
insihts:Price Range
1. Most prices are near 0: High density of prices concentrated near 0.
2. Long tail: Prices can extend to low values (around -7000).
3. Asymmetric distribution: Bulk of data near 0, spreading out unevenly.
4. Variation exists: Prices vary widely across the dataset.

# %% [markdown]
# ### 6.4 Top 10 Cities by Restaurant Count

# %%
top_cities = df['City'].value_counts().head(10).reset_index()
top_cities.columns = ['City', 'Restaurant Count']
plt.figure(figsize=(11,6))
sns.barplot(
    x='Restaurant Count',
    y='City',
    data=top_cities,
    hue='City',                             
    palette='crest'
)
plt.title('Top 10 Cities with Most Restaurants')
plt.xlabel('Restaurant Count')
plt.ylabel('City')
plt.show()

# %% [markdown]
# ## Insights

# %%
Insighs: Top 10 Cities by Restaurant Count
#1.Bangalore, Mumbai, and hyderabad have the highest number of restaurants on Swiggy.
#2.These metro cities dominate the food delivery market due to population density and demand.

# %% [markdown]
# ## 6.5 Ratings Distribution

# %%
plt.figure(figsize=(6,5))
sns.boxenplot(data=df,x="Rating")
plt.title("Ratings", fontsize=14)
plt.xlabel("Ratig", fontsize=12)
plt.show()

# %% [markdown]
# ## Insights:

# %% [markdown]
# insights:
# 1.Ratings mostly fall in the middle range.
# 2. Very few outliers are present.
# 3. Ratings show moderate variation.
# 4. Overall rating distribution is balanced.

# %% [markdown]
# ### 6.6 Average Rating per City

# %%
avg_rating = df.groupby('City')['Rating'].mean().sort_values(ascending=False).head(10)
plt.figure(figsize=(8,4))
avg_rating.plot(kind='bar', color='mediumslateblue', edgecolor='black')
plt.title('Average Rating per City')
plt.xlabel('City')
plt.ylabel('Average Rating')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## insights

# %%
Insights: Average Rating per City
# Smaller cities such as Chandigarh and Jaipur show higher average ratings than metros.
# This indicates that less competitive cities may provide better food quality or service.
# Larger cities, though having more options, see slightly lower satisfaction scores.

# %% [markdown]
# ### 6.7  Top 8 Dish Categories

# %%
plt.figure(figsize=(8,4))
df['Category'].value_counts().head(8).plot(kind='bar', color='lightcoral', edgecolor='black')
plt.title('Top 10 Dish Categories')
plt.xlabel('Category')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## insights

# %%
Insight 5: Top 8 Dish Categories
# North Indian, Chinese, and Fast Food are the most popular categories.
# These cuisines dominate across most cities, showing strong customer preference for familiar, quick meals.
# Global cuisines like Italian and Continental are less frequent but valued in select areas.

# %% [markdown]
# # 6.2 Bivariate Analysis

# %% [markdown]
# ## 6.2.1 Average Rating by Price Range

# %%
avg_rating = df.groupby('Price (INR)')['Rating'].mean().reset_index()
avg_rating.rename(columns={'Price (INR)': 'Price Range'}, inplace=True)

plt.figure(figsize=(10,5))
sns.lineplot(x='Price Range', y='Rating', data=avg_rating, marker='o', color='royalblue')
plt.title('Average Rating by Price Range')
plt.xlabel('Price Range')
plt.ylabel('Average Rating')
plt.grid(True)
plt.show()

# %% [markdown]
# ## insights:

# %%
insights:  Average Rating by Price Range
#1.As the price increases, the average rating also tends to rise slightly.
#2.This suggests that higher-priced restaurants are often rated better, indicating better quality or customer satisfaction.
#3.However, extremely high-priced options show limited rating improvement — implying diminishing returns on cost vs satisfaction.

# %% [markdown]
# ## 6.2.2 Average Price per Food Category

# %%
avg_category_price = df.groupby('Category')['Price (INR)'].mean().sort_values(ascending=False).head(10)
plt.figure(figsize=(8,4))
avg_category_price.plot(kind='bar', color='plum', edgecolor='black')
plt.title('Average Price per Food Category')
plt.xlabel('Category')
plt.ylabel('Average Price (INR)')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## insights

# %%
insights:
#1.Categories like partyspecials and party menu have the highest avarage prices.
#2.mid-range  priced items including Chefs Special Assorted Platte and Celebration Box Family and Mega Momos Platter.

# %% [markdown]
# ## 6.2.3 Top 10 Restaurants by Average Rating

# %%
top_restaurants = df.groupby('Restaurant Name')['Rating'].mean().sort_values(ascending=False).head(10)
plt.figure(figsize=(8,4))
top_restaurants.plot(kind='bar', color='blue', edgecolor='black')
plt.title('Top 10 Restaurants by Average Rating')
plt.xlabel('Restaurant Name')
plt.ylabel('Average Rating')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Insights

# %%
insights:Top 10 Restaurants by Average Rating
#1.Jagannath Mandir Anna Prasad has the highest average rating.
#2.All top 10 restaurants have ratings above 4.0, showing strong customer satisfaction.
#3.Sweets and family restaurants appear frequently among the top-rated ones.
#4.Customers generally give positive feedback to these popular places.

# %% [markdown]
# ## 6.2.4 Violin Plot of Price Distribution by State

# %%
plt.figure(figsize=(7,6))
top_states = df["State"].value_counts().head(10).index
sns.violinplot(data=df[df["State"].isin(top_states)], x="State", y="Price (INR)")
plt.title("Violin Plot of Price Distribution by State", fontsize=14)
plt.xlabel("State", fontsize=12)
plt.ylabel("Price Range", fontsize=12)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## insights

# %%
insights:  Violin Plot of Price Distribution by State
#1.Most states have similar median price levels.
#2.Price distribution is narrow → stable pricing across states.
#3.A few high-price outliers exist in major states.
#4.Delhi and Maharashtra show wider price variation.
#5.Majority of products fall in the low-price range.

# %% [markdown]
# ### 6.2. 5 Average Price per City

# %%
avg_price = df.groupby('City')['Price (INR)'].mean().sort_values(ascending=False).head(10)
plt.figure(figsize=(8,4))
avg_price.plot(kind='bar', color='lightseagreen', edgecolor='black')
plt.title('Average Price per City')
plt.xlabel('City')
plt.ylabel('Average Price (INR)')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Insights

# %%
Insights:
#1.Panaji has the highest average food price among all cities.
#2.Lucknow and Hyderabad follow closely with slightly lower average prices.
#3.Shimla and Shillong show the lowest average prices, indicating cheaper menu options.
#4.Overall, price variation across cities is moderate, suggesting similar pricing trends nationwide

# %% [markdown]
# ### 6.2.7 Average Rating per City

# %%
avg_rating = df.groupby('City')['Rating'].mean().sort_values(ascending=False).head(10)
plt.figure(figsize=(8,4))
avg_rating.plot(kind='bar', color='mediumslateblue', edgecolor='black')
plt.title('Average Rating per City')
plt.xlabel('City')
plt.ylabel('Average Rating')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Insights

# %%
Insights:  Average Rating per City
#1. Bhubaneswar has the highest rating.
#2. Most cities have ratings between 3.0 and 3.4.

# %% [markdown]
# ### 6.2.8 Price vs Rating

# %%
plt.figure(figsize=(6,4))
plt.scatter(df['Price (INR)'], df['Rating'], color='teal', alpha=0.6, edgecolors='black')
plt.title('Price vs Rating')
plt.xlabel('Price (INR)')
plt.ylabel('Rating')
plt.show()

# %% [markdown]
# ## Insights

# %%
Insight 7: Price vs Rating (Scatter)
#1 There is no strong relationship between price and rating.
#2 Both affordable and expensive restaurants receive similar ratings,
#3 showing that quality and service, not price, drive customer satisfaction.

# %% [markdown]
# ### 6.2.9 Rating Count vs Rating

# %%
plt.figure(figsize=(7,4))
plt.scatter(df['Rating Count'], df['Rating'], color='coral', alpha=0.6, edgecolors='black')
plt.title('Rating Count vs Rating')
plt.xlabel('Rating Count')
plt.ylabel('Rating')
plt.show()

# %% [markdown]
# ## Insights

# %%
insights:Rating Count vs Rating
#1.Most restaurants have ratings between 3.5 and 5, indicating generally positive feedback.
#2.A dense cluster is observed for ratings above 4, showing high customer satisfaction.
#3.Restaurants with higher rating counts also tend to have higher ratings, suggesting that popular places maintain good quality.
#4.Very few restaurants have low ratings (below 3)

# %% [markdown]
# ## 6.2.10 Box Plot-Distribution of price

# %%
plt.figure(figsize=(7,5))
sns.boxenplot(data=df,x="Price (INR)",y="State",color="lightcoral")
plt.title("Box Plot of Price Distribution Across Different State")
plt.ylabel("State")
plt.xlabel("price Range")
plt.show()

# %%
insights:   box Plot of Price Distribution Across Different State
1. **Most states have low-priced items — the majority of prices lie below ₹1000, showing that affordable products dominate the dataset.  
2. **Delhi and Maharashtra show high price variation, indicating a wider range of products from low to premium prices.  
3. **Outliers are present in multiple states, especially Delhi and Tamil Nadu, suggesting certain expensive items or premium categories.  
4. **Northeastern states (like Mizoram, Meghalaya, Nagaland)show a narrow price range, meaning more price consistency and fewer high-value items.

# %% [markdown]
# # 6.3 multivariate Analysis

# %% [markdown]
# ### 6.3.1 Correlation Between Numeric Features

# %%
plt.figure(figsize=(5,3))
sns.heatmap(df[['Price (INR)', 'Rating', 'Rating Count']].corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Between Numeric Features')
plt.show()

# %% [markdown]
#  ## Insights

# %%
insights:Correlation Between Numeric Features
#1.Rating Count and Rating show a positive correlation (0.26) — restaurants with more reviews often have slightly higher ratings.
#2.Price (INR) has a weak negative correlation with both Rating (-0.1) and Rating Count (-0.1) — higher prices don’t guarantee better ratings or more reviews.
#3.Overall, there is no strong correlation among numeric features, indicating they are mostly independent.

# %% [markdown]
# ### 6. 3.2 Pairwise Relationships Between Variables

# %%
sns.pairplot(df[['Price (INR)', 'Rating', 'Rating Count']], diag_kind='kde')
plt.suptitle('Pairwise Relationships Between Variables', y=1.02)
plt.show()

# %% [markdown]
# ## Insights

# %%
insights:Pairwise Relationships Between Variables
#1.Rating Count vs Rating: Slight positive relationship — restaurants with more reviews tend to have higher ratings.
#2.Price vs Rating: Weak or no visible relationship — higher price doesn’t ensure better ratings.
#3.Price vs Rating Count: Very weak or no correlation — expensive restaurants don’t always get more reviews.
#4.Most data points are clustered in lower price ranges and high ratings (4–5), showing that affordable and well-rated restaurants dominate.

# %% [markdown]
# # 7.Insights

# %% [markdown]
# 1.Rating Trends:
# #Most restaurants have moderate ratings (3.5–4.2), showing average satisfaction.
# #Few very high (4.8+) or very low (<3) ratings — Swiggy listings seem quality-filtered.
#
#
# 2.Price Distribution:
#
# #Majority of restaurants fall into low to mid-price ranges, indicating that affordable meals dominate Swiggy’s platform.
# #Premium restaurants are fewer but tend to have higher ratings, suggesting price–quality correlation.
#
#
# 3.Cuisines Popularity:
#
# #Indian, Chinese, and Fast Food are most frequent, aligning with national demand trends.
# #Lesser frequency of continental and Italian cuisines, which may have higher prices and limited audience.
#
#
#
# 4.City-Wise Trends:
#
# #Metro cities (like Bangalore, Hyderabad, and Mumbai) have higher restaurant density and more cuisine diversity.
# #Smaller cities show limited variety and lower average ratings.
#
#
#
# 5.Correlation Insights:
#
# #Slight positive correlation between rating and price range (i.e., higher prices = better reviews).
# #No strong correlation between delivery time and rating, meaning quality matters more than speed.
#
#
#
# 6.Customer Behavior Patterns:
#
# #Users prefer moderately priced restaurants with decent ratings over high-end ones.
# #Repeat patterns in cuisines across regions indicate stable taste preferences.

# %% [markdown]
# # 8.Conclusion

# %% [markdown]
# --->The Swiggy dataset reflects a price-sensitive but quality-aware customer base.
#
# ---->Ratings play a crucial role in customer decision-making.
#
# ---->Metro areas dominate restaurant listings and customer engagement.
#
# ---->Affordable Indian and Fast Food restaurants perform best overall.
#
#      To enhance business outcomes, Swiggy can:
#
#            - Promote high-rated affordable restaurants for better conversions.
#
#            - Encourage low-rated restaurants to improve via customer feedback.
